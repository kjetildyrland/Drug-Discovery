# %% [markdown]
# # Image Classification with DNN

# %% [markdown]
# ## DATASETS:
# (a) Carbonic Anhydrase II (ChEMBL205), a protein lyase,
# (b) Cyclin-dependent kinase 2 (CHEMBL301), a protein kinase,
# (c) ether-a-go-go-related gene potassium channel 1 (HERG) (CHEMBL240), a voltage-gated ion channel,
# (d) Dopamine D4 receptor (CHEMBL219), a monoamine GPCR,
# (e) Coagulation factor X (CHEMBL244), a serine protease,
# (f) Cannabinoid CB1 receptor (CHEMBL218), a lipid-like GPCR and
# (g) Cytochrome P450 19A1 (CHEMBL1978), a cytochrome P450.
# The activity classes were selected based on data availability and as representatives of therapeutically important target classes or as anti-targets.

# %%
# !nvidia-smi
# Out:
# Thu Apr 28 12:21:39 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.172.01   Driver Version: 450.172.01   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-DGXS...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   35C    P0    40W / 300W |    105MiB / 32505MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-DGXS...  On   | 00000000:08:00.0 Off |                    0 |
# | N/A   36C    P0    38W / 300W |      6MiB / 32508MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-DGXS...  On   | 00000000:0E:00.0 Off |                    0 |
# | N/A   36C    P0    37W / 300W |      6MiB / 32508MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-DGXS...  On   | 00000000:0F:00.0 Off |                    0 |
# | N/A   37C    P0    37W / 300W |      6MiB / 32508MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2917      G   /usr/lib/xorg/Xorg                 86MiB |
# |    0   N/A  N/A      3284      G   /usr/bin/gnome-shell               16MiB |
# |    1   N/A  N/A      2917      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A      2917      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A      2917      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %%
#%%capture
#!wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
#!chmod +x Miniconda3-latest-Linux-x86_64.sh
#!time bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
#!time conda install -q -y -c conda-forge rdkit

# %%
# Import
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
import os
sys.path.append('/usr/local/lib/python3.7/site-packages/')
from rdkit import Chem
from rdkit.Chem import AllChem
# Out:
# RDKit WARNING: [12:21:42] Enabling RDKit 2019.09.3 jupyter extensions
# [12:21:42] Enabling RDKit 2019.09.3 jupyter extensions

# %%
dataset = 'CHEMBL205'

# %%
path = Path('../dataset/13321_2017_226_MOESM1_ESM/')
df = pd.read_csv(path/f'{dataset}/{dataset}_cl.csv')

# %%
list(path.iterdir())
# Out:
# [PosixPath('../dataset/13321_2017_226_MOESM1_ESM/mol_images'),
#  PosixPath('../dataset/13321_2017_226_MOESM1_ESM/CHEMBL218'),
#  PosixPath('../dataset/13321_2017_226_MOESM1_ESM/CHEMBL219'),
#  PosixPath('../dataset/13321_2017_226_MOESM1_ESM/CHEMBL240'),
#  PosixPath('../dataset/13321_2017_226_MOESM1_ESM/CHEMBL244'),
#  PosixPath('../dataset/13321_2017_226_MOESM1_ESM/CHEMBL301'),
#  PosixPath('../dataset/13321_2017_226_MOESM1_ESM/CHEMBL205'),
#  PosixPath('../dataset/13321_2017_226_MOESM1_ESM/CHEMBL1978')]

# %%
DATA = path/'mol_images'

# %%
IMAGES = DATA/dataset

# %% [markdown]
# # Load DF

# %%
df = pd.read_csv(path/f'{dataset}/{dataset}_train_valid.csv')
df.head()
# Out:
#              CID                                             SMILES  Activity  \
# 0  CHEMBL1589687  S1c2n(ncn2)C(O)=C1C([NH+]1CCc2c(C1)cccc2)c1ccc...         0
# 1  CHEMBL3092937  S(=O)(=O)(N)c1cc(ccc1)-c1nnn(c1)C1OC(COC(=O)C)...         1
# 2   CHEMBL325684  O=C1N(Cc2ccc(cc2)-c2ccccc2C(=O)[O-])C(=NC12CC2...         0
# 3   CHEMBL488713  Fc1cc(F)c(F)cc1CC([NH3+])CC(=O)N1N=CCC1C(=O)Nc...         0
# 4  CHEMBL2069846  Fc1cc(F)c(F)cc1CC([NH3+])CC(=O)N1CCN(CC1)C(=O)...         0
#
#    is_valid
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %%
df_test = pd.read_csv(path/f'{dataset}/{dataset}_test1.csv')
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3589 entries, 0 to 3588
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CID       3589 non-null   object
#  1   SMILES    3589 non-null   object
#  2   Activity  3589 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 84.2+ KB

# %%
df_test.head()
# Out:
#              CID  \
# 0  CHEMBL1272094
# 1  CHEMBL1929412
# 2  CHEMBL3104775
# 3  CHEMBL1774231
# 4   CHEMBL426803
#
#                                                                SMILES  \
# 0                 S(=O)(=O)(C)c1cc2[nH]c(nc2cc1)-c1ncc(cc1)-c1ccccc1F
# 1                        [NH+]1(CCCCC1)Cc1ccc(NCc2nc3c(nc2N)cccc3)cc1
# 2  FC(F)(F)c1cc(cc(c1)C(F)(F)F)C(C(=O)NC(C(=O)NCC[NH3+])c1ccccc1)(C)C
# 3                FC(F)(F)c1cc(OC)c(cc1)C1CC[NH+](CC1C)Cc1nc2ncccc2n1C
# 4             S(=O)(=O)(N)c1ccc(N/C(/S)=N/C(CC(C)C)C(OCC(=O)NC)=O)cc1
#
#    Activity
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1

# %% [markdown]
# # Create dataloader

# %%
from fastai.vision.all import *

# %%
df['Image'] = df['CID'] + '.png'
df.head()
# Out:
#              CID  \
# 0  CHEMBL1589687
# 1  CHEMBL3092937
# 2   CHEMBL325684
# 3   CHEMBL488713
# 4  CHEMBL2069846
#
#                                                                         SMILES  \
# 0                         S1c2n(ncn2)C(O)=C1C([NH+]1CCc2c(C1)cccc2)c1ccc(F)cc1
# 1  S(=O)(=O)(N)c1cc(ccc1)-c1nnn(c1)C1OC(COC(=O)C)C(OC(=O)C)C(OC(=O)C)C1OC(=O)C
# 2                          O=C1N(Cc2ccc(cc2)-c2ccccc2C(=O)[O-])C(=NC12CC2)CCCC
# 3             Fc1cc(F)c(F)cc1CC([NH3+])CC(=O)N1N=CCC1C(=O)Nc1ccccc1OCC(=O)[O-]
# 4      Fc1cc(F)c(F)cc1CC([NH3+])CC(=O)N1CCN(CC1)C(=O)c1ccc(N2CC[NH+](CC2)C)cc1
#
#    Activity  is_valid              Image
# 0         0     False  CHEMBL1589687.png
# 1         1     False  CHEMBL3092937.png
# 2         0     False   CHEMBL325684.png
# 3         0     False   CHEMBL488713.png
# 4         0     False  CHEMBL2069846.png

# %%
images = df['CID'] + ".png"
images.head()
# Out:
# 0    CHEMBL1589687.png
# 1    CHEMBL3092937.png
# 2     CHEMBL325684.png
# 3     CHEMBL488713.png
# 4    CHEMBL2069846.png
# Name: CID, dtype: object

# %%
# No flips, some rotation and zoom. Normalize to imagenet_stats as
# we're using pretrained models.
batch_tfms = [*aug_transforms(mult=1.0, do_flip=False, flip_vert=False, 
               max_rotate=20.0, min_zoom=1.0, max_zoom=1.1, max_lighting=0., 
               max_warp=0., p_affine=0.75, p_lighting=0.75, xtra_tfms=None, 
               size=224, mode='bilinear', 
               pad_mode='border', align_corners=True, 
               batch=False, min_scale=1.0), 
              Normalize.from_stats(*imagenet_stats)]

# %%
db = DataBlock(
    blocks = (ImageBlock(), CategoryBlock()), 
    get_x=ColReader('Image', pref=IMAGES),
    get_y=ColReader('Activity'), 
    splitter=ColSplitter('is_valid'),
    item_tfms=None, 
    batch_tfms=batch_tfms,
    )

# %%
def get_df(dataset, test=False):
    if test:
        df = pd.read_csv(path/f'{dataset}/{dataset}_test1.csv')
    else:
        df = pd.read_csv(path/f'{dataset}/{dataset}_train_valid.csv')
    df['Image'] = df['CID'] + '.png'
    return df

# %%
def get_df_with_clusters(dataset, n_clusters=100, random_state=42, test_size=0.2):
    df = pd.read_csv(path/f'{dataset}/{dataset}_cl_ECFP_1024_with_{n_clusters}_clusters.csv')
    values = df.Cluster.value_counts(ascending=True)
    values = values[values < 2].index
    for i in list(values):
        df = df.drop(df[df.Cluster == i].index)
    df.reset_index(drop=True, inplace=True)
    x_train, x_valid = train_test_split(df.index, test_size=test_size, random_state=random_state, stratify=df['Cluster'])
    df.loc[x_train, 'is_valid']=False
    df.loc[x_valid, 'is_valid']=True
    df['Image'] = df['Name'] + '.png'
    return df

# %%
df = get_df(dataset)
df.head()
# Out:
#              CID  \
# 0  CHEMBL1589687
# 1  CHEMBL3092937
# 2   CHEMBL325684
# 3   CHEMBL488713
# 4  CHEMBL2069846
#
#                                                                         SMILES  \
# 0                         S1c2n(ncn2)C(O)=C1C([NH+]1CCc2c(C1)cccc2)c1ccc(F)cc1
# 1  S(=O)(=O)(N)c1cc(ccc1)-c1nnn(c1)C1OC(COC(=O)C)C(OC(=O)C)C(OC(=O)C)C1OC(=O)C
# 2                          O=C1N(Cc2ccc(cc2)-c2ccccc2C(=O)[O-])C(=NC12CC2)CCCC
# 3             Fc1cc(F)c(F)cc1CC([NH3+])CC(=O)N1N=CCC1C(=O)Nc1ccccc1OCC(=O)[O-]
# 4      Fc1cc(F)c(F)cc1CC([NH3+])CC(=O)N1CCN(CC1)C(=O)c1ccc(N2CC[NH+](CC2)C)cc1
#
#    Activity  is_valid              Image
# 0         0     False  CHEMBL1589687.png
# 1         1     False  CHEMBL3092937.png
# 2         0     False   CHEMBL325684.png
# 3         0     False   CHEMBL488713.png
# 4         0     False  CHEMBL2069846.png

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10764 entries, 0 to 10763
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CID       10764 non-null  object
#  1   SMILES    10764 non-null  object
#  2   Activity  10764 non-null  int64
#  3   is_valid  10764 non-null  bool
#  4   Image     10764 non-null  object
# dtypes: bool(1), int64(1), object(3)
# memory usage: 347.0+ KB

# %%
df_test = get_df(dataset, test=True)
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3589 entries, 0 to 3588
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CID       3589 non-null   object
#  1   SMILES    3589 non-null   object
#  2   Activity  3589 non-null   int64
#  3   Image     3589 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 112.3+ KB

# %%
df_test.head()
# Out:
#              CID  \
# 0  CHEMBL1272094
# 1  CHEMBL1929412
# 2  CHEMBL3104775
# 3  CHEMBL1774231
# 4   CHEMBL426803
#
#                                                                SMILES  \
# 0                 S(=O)(=O)(C)c1cc2[nH]c(nc2cc1)-c1ncc(cc1)-c1ccccc1F
# 1                        [NH+]1(CCCCC1)Cc1ccc(NCc2nc3c(nc2N)cccc3)cc1
# 2  FC(F)(F)c1cc(cc(c1)C(F)(F)F)C(C(=O)NC(C(=O)NCC[NH3+])c1ccccc1)(C)C
# 3                FC(F)(F)c1cc(OC)c(cc1)C1CC[NH+](CC1C)Cc1nc2ncccc2n1C
# 4             S(=O)(=O)(N)c1ccc(N/C(/S)=N/C(CC(C)C)C(OCC(=O)NC)=O)cc1
#
#    Activity              Image
# 0         0  CHEMBL1272094.png
# 1         0  CHEMBL1929412.png
# 2         0  CHEMBL3104775.png
# 3         0  CHEMBL1774231.png
# 4         1   CHEMBL426803.png

# %%
IMAGES = DATA/dataset
IMAGES
# Out:
# Path('../dataset/13321_2017_226_MOESM1_ESM/mol_images/CHEMBL205')

# %%
def get_dls(dataset, bs=64, clustering=False, random_state=42, test=False):
    IMAGES = DATA/dataset
    if clustering:
        df = get_df_with_clusters(dataset, n_clusters=100)
    else:
        df = get_df(dataset, test=test)
    if test:
        db = DataBlock(
        blocks = (ImageBlock(), CategoryBlock()), 
        get_x=ColReader('Image', pref=IMAGES),
        get_y=ColReader('Activity'), 
        splitter=IndexSplitter([]),
        item_tfms=None, 
        batch_tfms=None,
        )
        dls = db.dataloaders(df, bs=32, shuffle_train=False)
    else:
        db = DataBlock(
            blocks = (ImageBlock(), CategoryBlock()), 
            get_x=ColReader('Image', pref=IMAGES),
            get_y=ColReader('Activity'), 
            splitter=ColSplitter('is_valid'),
            item_tfms=None, 
            batch_tfms=None,
            )
        dls = db.dataloaders(df, bs=bs, shuffle_train=True, random_state=42)
    return dls, df

# %%
dls, df = get_dls(dataset, clustering=False)

# %%
dls.show_batch()

# %%
dls.show_batch(unique=True)

# %%
test_dls, test_df = get_dls(dataset, test=True)

# %%
test_dls.show_batch()

# %%
test_dls.show_batch()

# %%
tdf, y = test_dls.one_batch()
y[0:5]
# Out:
# TensorCategory([0, 0, 0, 0, 1], device='cuda:0')

# %% [markdown]
# # Create class weights

# %%
TARGET = 'Activity'

# %%
class_count_df = df.groupby(TARGET).count()
class_count_df
# Out:
#            CID  SMILES  is_valid  Image
# Activity
# 0         9785    9785      9785   9785
# 1          979     979       979    979

# %%
n_0, n_1 = class_count_df.iloc[0, 0], class_count_df.iloc[1, 0]

# %%
w_0 = (n_0 + n_1) / (2.0 * n_0)
w_1 = (n_0 + n_1) / (2.0 * n_1)
w_0, w_1
# Out:
# (0.5500255493101687, 5.4974463738508685)

# %%
class_weights=torch.FloatTensor([w_0, w_1]).cuda()

# %%
loss_func = CrossEntropyLossFlat(weight=class_weights)

# %%
def get_loss_func(df):
    TARGET = 'Activity'
    class_count_df = df.groupby(TARGET).count()
    n_0, n_1 = class_count_df.iloc[0, 0], class_count_df.iloc[1, 0]
    w_0 = (n_0 + n_1) / (2.0 * n_0)
    w_1 = (n_0 + n_1) / (2.0 * n_1)
    class_weights=torch.FloatTensor([w_0, w_1]).cuda()
    loss_func = CrossEntropyLossFlat(weight=class_weights)
    return loss_func

# %%
loss_func=get_loss_func(df)

# %% [markdown]
# # Train CNN model

# %%
from sklearn.metrics import auc,roc_auc_score,recall_score,precision_score,f1_score
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import accuracy_score

# %%
from fastai.callback.hook import *

# %%
def train_model(dls, arch=resnet18, loss_func=None, epochs=16, wd=None, lr=None):
    
    
    print(f'Architechture: {arch}')
    #print(f'Untrained epochs: freeze_epochs={freeze_epochs}')
    print(f'Trained epochs: epochs={epochs}')
    print(f'Weight decay: wd={wd}')
    learn = cnn_learner(dls, arch=arch, pretrained=True, 
                            wd=wd,
                            loss_func=loss_func,
                            metrics=[accuracy, 
                            F1Score(), 
                            Precision(), 
                            Recall(), 
                            RocAucBinary(), 
                            MatthewsCorrCoef()])
    
    if lr == None: 
        print(f'Finding learning rate...')
        lr_min, lr_steep = learn.lr_find(suggestions=True, show_plot=False)
        print(f'Training model with learning rate: {lr_min}')
        lr = lr_min
    else: 
        print(f'Training model with learning rate: {lr}')
    learn.fine_tune(epochs, lr)
    
    return learn

# %%
# Train model on resnet18
learn = train_model(dls, epochs=30,lr=1e-4, wd=0.0002)
# Out:
# Architechture: <function resnet18 at 0x7f1194ed3560>
# Trained epochs: epochs=30
# Weight decay: wd=0.0002
# Training model with learning rate: 0.0001
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.087290</td>
#       <td>0.717452</td>
#       <td>0.637250</td>
#       <td>0.309461</td>
#       <td>0.187166</td>
#       <td>0.892857</td>
#       <td>0.854627</td>
#       <td>0.292794</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.955444</td>
#       <td>0.662094</td>
#       <td>0.669299</td>
#       <td>0.327032</td>
#       <td>0.200696</td>
#       <td>0.882653</td>
#       <td>0.874154</td>
#       <td>0.311502</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0
td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.139242</td>
#       <td>0.170505</td>
#       <td>0.959127</td>
#       <td>0.787440</td>
#       <td>0.747706</td>
#       <td>0.831633</td>
#       <td>0.964399</td>
#       <td>0.766224</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.129393</td>
#       <td>0.190290</td>
#       <td>0.958662</td>
#       <td>0.788599</td>
#       <td>0.737778</td>
#       <td>0.846939</td>
#       <td>0.964438</td>
#       <td>0.768050</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.108599</td>
#       <td>0.193935</td>
#       <td>0.959591</td>
#       <td>0.791367</td>
#       <td>0.746606</td>
#       <td>0.841837</td>
#       <td>0.963216</td>
#       <td>0.770784</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.100617</td>
#       <td>0.193734</td>
#       <td>0.961449</td>
#       <td>0.798054</td>
#       <td>0.762791</td>
#       <td>0.836735</td>
#       <td>0.965352</td>
#       <td>0.777810</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.093945</td>
#       <td>0.180456</td>
#       <td>0.961449</td>
#       <td>0.796069</td>
#       <td>0.767773</td>
#       <td>0.826531</td>
#       <td>0.967296</td>
#       <td>0.775456</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.087102</td>
#       <td>0.202320</td>
#       <td>0.958662</td>
#       <td>0.787589</td>
#       <td>0.739910</td>
#       <td>0.841837</td>
#       <td>0.967971</td>
#       <td>0.766752</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.082363</td>
#       <td>0.177989</td>
#       <td>0.962378</td>
#       <td>0.798005</td>
#       <td>0.780488</td>
#       <td>0.816327</td>
#       <td>0.964556</td>
#       <td>0.777512</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.075617</td>
#       <td>0.188190</td>
#       <td>0.962378</td>
#       <td>0.801956</td>
#       <td>0.769953</td>
#       <td>0.836735</td>
#       <td>0.964674</td>
#       <td>0.782035</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.083610</td>
#       <td>0.181613</td>
#       <td>0.962378</td>
#       <td>0.799007</td>
#       <td>0.777778</td>
#       <td>0.821429</td>
#       <td>0.965207</td>
#       <td>0.778624</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.071179</td>
#       <td>0.182029</td>
#       <td>0.962843</td>
#       <td>0.801980</td>
#       <td>0.778846</td>
#       <td>0.826531</td>
#       <td>0.966223</td>
#       <td>0.781918</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.082002</td>
#       <td>0.196752</td>
#       <td>0.961914</td>
#       <td>0.801932</td>
#       <td>0.761468</td>
#       <td>0.846939</td>
#       <td>0.966644</td>
#       <td>0.782282</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.069587</td>
#       <td>0.182231</td>
#       <td>0.962843</td>
#       <td>0.801980</td>
#       <td>0.778846</td>
#       <td>0.826531</td>
#       <td>0.965115</td>
#       <td>0.781918</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.077946</td>
#       <td>0.176661</td>
#       <td>0.963307</td>
#       <td>0.802993</td>
#       <td>0.785366</td>
#       <td>0.821429</td>
#       <td>0.964900</td>
#       <td>0.783013</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn, dl=test_dls.train)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /home/mmiv-ml/anaconda3/envs/fastai-drug/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(k=10)

# %% [markdown]
# # Get the models output

# %%
def get_prediction_output(model, dl):
    predictions = pd.DataFrame()
    for inputs, y in dl:
        p = pd.DataFrame([])
        p['class'] = y.cpu().detach().numpy()
        preds = model.get_preds(inputs)
        p['predictions'] = list(preds.cpu().detach().numpy())
        predictions = pd.concat([predictions, p], ignore_index=True)
    return predictions

# %%
preds, y, y_pred, y_input = learn.get_preds(dl=test_dls.train, with_decoded=True, with_loss=True)
preds[0:5], y[0:5], y_pred[0:5], y_input[0:5]
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /home/mmiv-ml/anaconda3/envs/fastai-drug/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (tensor([[0.9955, 0.0045],
#          [0.9973, 0.0027],
#          [0.9892, 0.0108],
#          [0.9956, 0.0044],
#          [0.9957, 0.0043]]),
#  TensorCategory([0, 0, 0, 0, 1]),
#  tensor([0, 0, 0, 0, 0]),
#  TensorBase([4.4675e-03, 2.7494e-03, 1.0844e-02, 4.3878e-03, 5.4467e+00]))

# %%
preds = get_prediction_output(learn, test_dls.train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_906077/4087549814.py in <module>
# ----> 1 preds = get_prediction_output(learn, test_dls.train)
#
# /tmp/ipykernel_906077/3072943269.py in get_prediction_output(model, dl)
#       4         p = pd.DataFrame([])
#       5         p['class'] = y.cpu().detach().numpy()
# ----> 6         preds = model.get_preds(inputs)
#       7         p['predictions'] = list(preds.cpu().detach().numpy())
#       8         predictions = pd.concat([predictions, p], ignore_index=True)
#
# ~/anaconda3/envs/fastai-drug/lib/python3.7/site-packages/fastai/learner.py in get_preds(self, ds_idx, dl, with_input, with_decoded, with_loss, act, inner, reorder, cbs, **kwargs)
#     224     def get_preds(self, ds_idx=1, dl=None, with_input=False, with_decoded=False, with_loss=False, act=None,
#     225                   inner=False, reorder=True, cbs=None, **kwargs):
# --> 226         if dl is None: dl = self.dls[ds_idx].new(shuffled=False, drop_last=False)
#     227         else:
#     228             try: len(dl)
#
# ~/anaconda3/envs/fastai-drug/lib/python3.7/site-packages/fastai/data/core.py in __getitem__(self, i)
#     142         if device is not None or hasattr(loaders[0],'to'): self.device = device
#     143
# --> 144     def __getitem__(self, i): return self.loaders[i]
#     145     def new_empty(self):
#     146         loaders = [dl.new(dl.dataset.new_empty()) for dl in self.loaders]
#
# ~/anaconda3/envs/fastai-drug/lib/python3.7/site-packages/fastai/torch_core.py in __torch_function__(self, func, types, args, kwargs)
#     317 #         if func.__name__[0]!='_': print(func, types, args, kwargs)
#     318 #         with torch._C.DisableTorchFunction(): ret = _convert(func(*args, **(kwargs or {})), self.__class__)
# --> 319         ret = super().__torch_function__(func, types, args=args, kwargs=kwargs)
#     320         if isinstance(ret, TensorBase): ret.set_meta(self, as_copy=True)
#     321         return ret
#
# ~/anaconda3/envs/fastai-drug/lib/python3.7/site-packages/torch/_tensor.py in __torch_function__(cls, func, types, args, kwargs)
#    1021
#    1022         with _C.DisableTorchFunction():
# -> 1023             ret = func(*args, **kwargs)
#    1024             return _convert(ret, cls)
#    1025
#
# TypeError: only integer tensors of a single element can be converted to an index

# %%
preds.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_906077/3032548700.py in <module>
# ----> 1 preds.head()
#
# NameError: name 'preds' is not defined

# %%
preds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3589 entries, 0 to 3588
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   class        3589 non-null   int64
#  1   predictions  3589 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 56.2+ KB

# %%
preds.to_csv(path/f'{dataset}/{dataset}_predictions_CNN.csv', index=False)

# %% [markdown]
# # Test different regularizations

# %% [markdown]
# ## Results:
# ### wd = 0.002 is good for around 15-20 epochs before overfitting
# ### lr = 3e-3 is good for most CNNs and also in this case
# ### dropout = 0.5 is a usually sustainable

# %%
from sklearn.model_selection import ParameterGrid

# %%
# wd = 0.002 works for around 15-20 epochs
# lr = 3e-3 is good most CNN and in this case
# dropout = 0.5 is a usually sustainable
# batch_size = 64
param_grid={
    "bs" : [128, 252, 512],
}
param_grid = ParameterGrid(param_grid)

for p in param_grid:
    dls = get_dls(dataset, bs=p['bs'])
    learn = train_model(dls, loss_func=loss_func, epochs=15, wd=0.002, lr=3e-3)

# %% [markdown]
# # Test random state

# %% [markdown]
# **Results:** Random state has a huge impact \
# **Tip:** Try clustering methods

# %%
random_states = [1,4,42,666]

# %%
for r in random_states:
    dls = get_dls(dataset, df, random_state=r)
    learn = train_model(dls, epochs=10, lr=3e-3)

# %% [markdown]
# # Compare architechtures

# %% [markdown]
# **Results:** Not much difference between **Resnet18, Resnet34 and Resnet50** on (224, 224) size images. \
# **Alexnet** got worse results then **resnet**. \
# Reason could be that the extra layers is not much of a use in this case (i.e. The images does not contain a lot of details) \
# **Resnet18** takes less time to train due to less layers and therefore should be used in this case.

# %%
archs =  [resnet18, resnet50, alexnet]

# %%
for arch in archs:
    train_model(dls, arch=arch, epochs=15, lr=3e-3)

# %% [markdown]
# # Test clustering

# %%
def train_on_dataset(learn = None, dataset, clustering = False):
    print(f'Training model on dataset: {dataset}')
    dls, df = get_dls(dataset, clustering=clustering)
    loss_func = get_loss_func(df)
    if learn == None:
        learn = train_model(dls, epochs = 10, lr=3e-3, loss_func=loss_func)
    else:
        learn = learn
        learn.dls = dls
        learn.fit()
    return learn

# %%
learn = train_on_dataset(dataset, clustering=True)

# %%
learn2 = train_on_dataset(dataset)

# %% [markdown]
# # Train on all datasets and store model

# %%
datasets = ['CHEMBL205',  'CHEMBL301',  
            'CHEMBL240', 'CHEMBL219', 
            'CHEMBL244', 'CHEMBL218',
           'CHEMBL1978',]

# %%
top_mcc_scores = {
    
    'CHEMBL205': 0.862,
    'CHEMBL301': 0.926,
    'CHEMBL240': 0.884,
    'CHEMBL219': 0.887,
    'CHEMBL244': 0.983,
    'CHEMBL218': 0.941,
    'CHEMBL1978': 0.904}

# %%
def train_on_dataset(dataset, learn=None, epochs=30, clustering = False):
    print(f'Training model on dataset: {dataset}')
    dls, df = get_dls(dataset, clustering=clustering)
    loss_func = get_loss_func(df)
    if learn == None:
        learn = train_model(dls, arch=resnet18, epochs = epochs, lr=None, loss_func=loss_func)
    else:
        learn = learn
        learn.dls = dls
        #lr_min, lr_steep = learn.lr_find(suggestions=True, show_plot=False)
        learn.fine_tune(epochs, 3e-3, wd=0.0002)
    return learn

# %%
learn = train_on_dataset(datasets[0])
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
interp.plot_top_losses(k=25)
learn.export(fname= f'models/{datasets[0]}')

# %%
for dataset in datasets: 
    learn = train_on_dataset(dataset)
    interp = ClassificationInterpretation.from_learner(learn)
    interp.plot_confusion_matrix()
    interp.plot_top_losses(k=5)
    learn.export(fname= f'models/{dataset}.pkl')
# Out:
# Training model on dataset: CHEMBL205
# Architechture: <function resnet18 at 0x7ff0923e2560>
# Trained epochs: epochs=30
# Weight decay: wd=None
# Finding learning rate...
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# # Transfer learning

# %% [markdown]
# ### Idea: Create a model that performs good on all datasets after a couple of epochs

# %%
datasets = ['CHEMBL205',  'CHEMBL301',  
            'CHEMBL240', 'CHEMBL219', 
            'CHEMBL244', 'CHEMBL218',
           'CHEMBL1978',]

# %%
learn = train_on_dataset(datasets[0], epochs=5)
# Out:
# Training model on dataset: CHEMBL205
# Architechture: <function resnet18 at 0x7f6aef3e3d40>
# Trained epochs: epochs=5
# Weight decay: wd=None
# Finding learning rate...
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Training model with learning rate: 0.00831763744354248
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.508482</td>
#       <td>0.364152</td>
#       <td>0.902480</td>
#       <td>0.630802</td>
#       <td>0.480707</td>
#       <td>0.917178</td>
#       <td>0.961326</td>
#       <td>0.621180</td>
#       <td>00:32</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.308266</td>
#       <td>0.139736</td>
#       <td>0.958763</td>
#       <td>0.773006</td>
#       <td>0.773006</td>
#       <td>0.773006</td>
#       <td>0.965882</td>
#       <td>0.750328</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.287860</td>
#       <td>0.311957</td>
#       <td>0.901644</td>
#       <td>0.639428</td>
#       <td>0.479326</td>
#       <td>0.960123</td>
#       <td>0.974766</td>
#       <td>0.637555</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.190809</td>
#       <td>0.150745</td>
#       <td>0.953748</td>
#       <td>0.781003</td>
#       <td>0.685185</td>
#       <td>0.907975</td>
#       <td>0.979863</td>
#       <td>0.765076</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.114694</td>
#       <td>0.126239</td>
#       <td>0.959320</td>
#       <td>0.808901</td>
#       <td>0.705479</td>
#       <td>0.947853</td>
#       <td>0.987528</td>
#       <td>0.797433</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.069320</td>
#       <td>0.116890</td>
#       <td>0.968515</td>
#       <td>0.844138</td>
#       <td>0.766917</td>
#       <td>0.938650</td>
#       <td>0.987443</td>
#       <td>0.832047</td>
#       <td>00:41</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %%
learn.recorder.plot_sched()

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
interp.plot_top_losses(k=10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn = train_on_dataset(datasets[1], learn, epochs=5)
# Out:
# Training model on dataset: CHEMBL301
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.311723</td>
#       <td>0.362595</td>
#       <td>0.847195</td>
#       <td>0.494670</td>
#       <td>0.353659</td>
#       <td>0.822695</td>
#       <td>0.920497</td>
#       <td>0.473324</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.307457</td>
#       <td>0.376523</td>
#       <td>0.840103</td>
#       <td>0.491803</td>
#       <td>0.345821</td>
#       <td>0.851064</td>
#       <td>0.921342</td>
#       <td>0.476031</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.301280</td>
#       <td>0.389578</td>
#       <td>0.833011</td>
#       <td>0.480962</td>
#       <td>0.335196</td>
#       <td>0.851064</td>
#       <td>0.921443</td>
#       <td>0.465493</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.303013</td>
#       <td>0.363307</td>
#       <td>0.847195</td>
#       <td>0.496815</td>
#       <td>0.354545</td>
#       <td>0.829787</td>
#       <td>0.921196</td>
#       <td>0.476757</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.300111</td>
#       <td>0.364379</td>
#       <td>0.850419</td>
#       <td>0.502146</td>
#       <td>0.360000</td>
#       <td>0.829787</td>
#       <td>0.921503</td>
#       <td>0.481935</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.304614</td>
#       <td>0.358110</td>
#       <td>0.854288</td>
#       <td>0.508696</td>
#       <td>0.366771</td>
#       <td>0.829787</td>
#       <td>0.921835</td>
#       <td>0.488286</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
interp.plot_top_losses(k=10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn=None

# %%
for i in range(20):
    for d in datasets:
        learn = train_on_dataset(d, learn=learn, epochs=1)
# Out:
# Training model on dataset: CHEMBL205
# Architechture: <function resnet34 at 0x7f6aef3e3dd0>
# Trained epochs: epochs=1
# Weight decay: wd=None
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /home/kjetil/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# Finding learning rate...
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Training model with learning rate: 0.002290867641568184
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.571189</td>
#       <td>0.432852</td>
#       <td>0.841739</td>
#       <td>0.508651</td>
#       <td>0.354217</td>
#       <td>0.901840</td>
#       <td>0.933903</td>
#       <td>0.502699</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.246068</td>
#       <td>0.217650</td>
#       <td>0.938144</td>
#       <td>0.737589</td>
#       <td>0.600000</td>
#       <td>0.957055</td>
#       <td>0.980589</td>
#       <td>0.729322</td>
#       <td>01:05</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL301
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.657814</td>
#       <td>0.492963</td>
#       <td>0.804642</td>
#       <td>0.372671</td>
#       <td>0.263158</td>
#       <td>0.638298</td>
#       <td>0.821588</td>
#       <td>0.318676</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.426422</td>
#       <td>0.246227</td>
#       <td>0.911670</td>
#       <td>0.647815</td>
#       <td>0.508065</td>
#       <td>0.893617</td>
#       <td>0.964358</td>
#       <td>0.633059</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL240
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.780535</td>
#       <td>0.479751</td>
#       <td>0.753896</td>
#       <td>0.314647</td>
#       <td>0.210654</td>
#       <td>0.621429</td>
#       <td>0.763107</td>
#       <td>0.252152</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.482226</td>
#       <td>0.455379</td>
#       <td>0.779870</td>
#       <td>0.406305</td>
#       <td>0.269142</td>
#       <td>0.828571</td>
#       <td>0.882949</td>
#       <td>0.386502</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL219
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.506287</td>
#       <td>0.531442</td>
#       <td>0.748653</td>
#       <td>0.375000</td>
#       <td>0.242075</td>
#       <td>0.831683</td>
#       <td>0.864318</td>
#       <td>0.354685</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.415569</td>
#       <td>0.415718</td>
#       <td>0.823160</td>
#       <td>0.490956</td>
#       <td>0.332168</td>
#       <td>0.940594</td>
#       <td>0.942138</td>
#       <td>0.494323</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL244
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.509092</td>
#       <td>0.368530</td>
#       <td>0.833929</td>
#       <td>0.481390</td>
#       <td>0.336222</td>
#       <td>0.847162</td>
#       <td>0.920071</td>
#       <td>0.465068</td>
#       <td>00:37</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.230655</td>
#       <td>0.205150</td>
#       <td>0.924116</td>
#       <td>0.700157</td>
#       <td>0.546569</td>
#       <td>0.973799</td>
#       <td>0.988680</td>
#       <td>0.696788</td>
#       <td>00:46</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL218
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.507937</td>
#       <td>0.463464</td>
#       <td>0.779928</td>
#       <td>0.392881</td>
#       <td>0.262555</td>
#       <td>0.780105</td>
#       <td>0.866418</td>
#       <td>0.362783</td>
#       <td>01:01</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.229302</td>
#       <td>0.176328</td>
#       <td>0.935245</td>
#       <td>0.724313</td>
#       <td>0.592346</td>
#       <td>0.931937</td>
#       <td>0.985459</td>
#       <td>0.712443</td>
#       <td>01:16</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL1978
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.708845</td>
#       <td>0.465350</td>
#       <td>0.770300</td>
#       <td>0.389105</td>
#       <td>0.256410</td>
#       <td>0.806452</td>
#       <td>0.867419</td>
#       <td>0.364528</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.270869</td>
#       <td>0.246783</td>
#       <td>0.901975</td>
#       <td>0.639785</td>
#       <td>0.479839</td>
#       <td>0.959677</td>
#       <td>0.973380</td>
#       <td>0.637862</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL205
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.319405</td>
#       <td>0.234192</td>
#       <td>0.914739</td>
#       <td>0.662252</td>
#       <td>0.517241</td>
#       <td>0.920245</td>
#       <td>0.966825</td>
#       <td>0.651455</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.212764</td>
#       <td>0.215630</td>
#       <td>0.925606</td>
#       <td>0.704319</td>
#       <td>0.551127</td>
#       <td>0.975460</td>
#       <td>0.982110</td>
#       <td>0.701054</td>
#       <td>01:06</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL301
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.796425</td>
#       <td>0.447141</td>
#       <td>0.789168</td>
#       <td>0.384181</td>
#       <td>0.261538</td>
#       <td>0.723404</td>
#       <td>0.851954</td>
#       <td>0.344003</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.322322</td>
#       <td>0.293894</td>
#       <td>0.885235</td>
#       <td>0.597285</td>
#       <td>0.438538</td>
#       <td>0.936170</td>
#       <td>0.963528</td>
#       <td>0.593386</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL240
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.657356</td>
#       <td>0.443912</td>
#       <td>0.770130</td>
#       <td>0.372340</td>
#       <td>0.247642</td>
#       <td>0.750000</td>
#       <td>0.859286</td>
#       <td>0.336049</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.407230</td>
#       <td>0.347188</td>
#       <td>0.848701</td>
#       <td>0.503198</td>
#       <td>0.358663</td>
#       <td>0.842857</td>
#       <td>0.926602</td>
#       <td>0.485460</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL219
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.587443</td>
#       <td>0.488823</td>
#       <td>0.782765</td>
#       <td>0.395000</td>
#       <td>0.264214</td>
#       <td>0.782178</td>
#       <td>0.847742</td>
#       <td>0.366101</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.415160</td>
#       <td>0.437915</td>
#       <td>0.794434</td>
#       <td>0.445521</td>
#       <td>0.294872</td>
#       <td>0.910891</td>
#       <td>0.922131</td>
#       <td>0.443590</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL244
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.476758</td>
#       <td>0.364782</td>
#       <td>0.843862</td>
#       <td>0.491591</td>
#       <td>0.349265</td>
#       <td>0.829694</td>
#       <td>0.922647</td>
#       <td>0.471596</td>
#       <td>00:36</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.212435</td>
#       <td>0.210480</td>
#       <td>0.935240</td>
#       <td>0.728785</td>
#       <td>0.588710</td>
#       <td>0.956332</td>
#       <td>0.987117</td>
#       <td>0.720755</td>
#       <td>00:45</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL218
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.364261</td>
#       <td>0.274864</td>
#       <td>0.901075</td>
#       <td>0.621572</td>
#       <td>0.477528</td>
#       <td>0.890052</td>
#       <td>0.960648</td>
#       <td>0.607234</td>
#       <td>01:00</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.176433</td>
#       <td>0.168118</td>
#       <td>0.941697</td>
#       <td>0.746362</td>
#       <td>0.618966</td>
#       <td>0.939791</td>
#       <td>0.987365</td>
#       <td>0.734917</td>
#       <td>01:15</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL1978
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.652489</td>
#       <td>0.367998</td>
#       <td>0.817118</td>
#       <td>0.449339</td>
#       <td>0.309091</td>
#       <td>0.822581</td>
#       <td>0.899956</td>
#       <td>0.428949</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.225989</td>
#       <td>0.230256</td>
#       <td>0.906364</td>
#       <td>0.650273</td>
#       <td>0.491736</td>
#       <td>0.959677</td>
#       <td>0.973808</td>
#       <td>0.647629</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL205
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.246529</td>
#       <td>0.211171</td>
#       <td>0.932293</td>
#       <td>0.718424</td>
#       <td>0.577281</td>
#       <td>0.950920</td>
#       <td>0.977650</td>
#       <td>0.710048</td>
#       <td>00:51</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.154226</td>
#       <td>0.183682</td>
#       <td>0.942881</td>
#       <td>0.755662</td>
#       <td>0.617934</td>
#       <td>0.972393</td>
#       <td>0.984162</td>
#       <td>0.749058</td>
#       <td>01:05</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL301
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.434888</td>
#       <td>0.248455</td>
#       <td>0.892328</td>
#       <td>0.593674</td>
#       <td>0.451852</td>
#       <td>0.865248</td>
#       <td>0.959791</td>
#       <td>0.576419</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.188605</td>
#       <td>0.168217</td>
#       <td>0.935525</td>
#       <td>0.725275</td>
#       <td>0.591928</td>
#       <td>0.936170</td>
#       <td>0.983064</td>
#       <td>0.714168</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL240
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.749057</td>
#       <td>0.313408</td>
#       <td>0.873377</td>
#       <td>0.459834</td>
#       <td>0.375566</td>
#       <td>0.592857</td>
#       <td>0.865469</td>
#       <td>0.405310</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.295801</td>
#       <td>0.283272</td>
#       <td>0.887662</td>
#       <td>0.572840</td>
#       <td>0.437736</td>
#       <td>0.828571</td>
#       <td>0.929791</td>
#       <td>0.550013</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL219
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.467959</td>
#       <td>0.366546</td>
#       <td>0.848294</td>
#       <td>0.512968</td>
#       <td>0.361789</td>
#       <td>0.881188</td>
#       <td>0.917967</td>
#       <td>0.502685</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.320489</td>
#       <td>0.321949</td>
#       <td>0.863555</td>
#       <td>0.558140</td>
#       <td>0.395062</td>
#       <td>0.950495</td>
#       <td>0.953017</td>
#       <td>0.559957</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL244
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.240737</td>
#       <td>0.207311</td>
#       <td>0.915773</td>
#       <td>0.667712</td>
#       <td>0.520782</td>
#       <td>0.930131</td>
#       <td>0.977137</td>
#       <td>0.658311</td>
#       <td>00:36</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.102916</td>
#       <td>0.095536</td>
#       <td>0.967819</td>
#       <td>0.842718</td>
#       <td>0.758741</td>
# ...
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.608297</td>
#       <td>0.275380</td>
#       <td>0.889610</td>
#       <td>0.545455</td>
#       <td>0.435897</td>
#       <td>0.728571</td>
#       <td>0.907413</td>
#       <td>0.507965</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.240770</td>
#       <td>0.205137</td>
#       <td>0.925325</td>
#       <td>0.670487</td>
#       <td>0.559809</td>
#       <td>0.835714</td>
#       <td>0.956816</td>
#       <td>0.646333</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL219
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.448012</td>
#       <td>0.361745</td>
#       <td>0.859066</td>
#       <td>0.539589</td>
#       <td>0.383333</td>
#       <td>0.910891</td>
#       <td>0.929520</td>
#       <td>0.534129</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.295948</td>
#       <td>0.268762</td>
#       <td>0.902154</td>
#       <td>0.635452</td>
#       <td>0.479798</td>
#       <td>0.940594</td>
#       <td>0.966690</td>
#       <td>0.630091</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL244
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.786917</td>
#       <td>0.452137</td>
#       <td>0.804529</td>
#       <td>0.327869</td>
#       <td>0.238569</td>
#       <td>0.524017</td>
#       <td>0.771781</td>
#       <td>0.256472</td>
#       <td>00:36</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.392521</td>
#       <td>0.286530</td>
#       <td>0.884783</td>
#       <td>0.557927</td>
#       <td>0.428571</td>
#       <td>0.799127</td>
#       <td>0.927091</td>
#       <td>0.530601</td>
#       <td>00:46</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL218
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.206778</td>
#       <td>0.153445</td>
#       <td>0.941935</td>
#       <td>0.740662</td>
#       <td>0.625225</td>
#       <td>0.908377</td>
#       <td>0.981096</td>
#       <td>0.724923</td>
#       <td>01:00</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.076577</td>
#       <td>0.080327</td>
#       <td>0.972043</td>
#       <td>0.855734</td>
#       <td>0.808858</td>
#       <td>0.908377</td>
#       <td>0.988947</td>
#       <td>0.842047</td>
#       <td>01:15</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL1978
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.664453</td>
#       <td>0.339011</td>
#       <td>0.861741</td>
#       <td>0.531017</td>
#       <td>0.383513</td>
#       <td>0.862903</td>
#       <td>0.931831</td>
#       <td>0.516280</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.108145</td>
#       <td>0.123882</td>
#       <td>0.956840</td>
#       <td>0.795848</td>
#       <td>0.696970</td>
#       <td>0.927419</td>
#       <td>0.977370</td>
#       <td>0.782115</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL205
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.216579</td>
#       <td>0.166289</td>
#       <td>0.946503</td>
#       <td>0.758794</td>
#       <td>0.642553</td>
#       <td>0.926380</td>
#       <td>0.969475</td>
#       <td>0.745274</td>
#       <td>00:51</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.091210</td>
#       <td>0.134188</td>
#       <td>0.960435</td>
#       <td>0.812665</td>
#       <td>0.712963</td>
#       <td>0.944785</td>
#       <td>0.984413</td>
#       <td>0.800833</td>
#       <td>01:05</td>
#     </tr>
#   </tbody>
# </table>
# Training model on dataset: CHEMBL301
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_279755/1812572905.py in <module>
#       1 for i in range(20):
#       2     for d in datasets:
# ----> 3         learn = train_on_dataset(d, learn=learn, epochs=1)
#
# /tmp/ipykernel_279755/4096260946.py in train_on_dataset(dataset, learn, epochs, clustering)
#       8         learn = learn
#       9         learn.dls = dls
# ---> 10         lr_min, lr_steep = learn.lr_find(suggestions=True, show_plot=False)
#      11         learn.fine_tune(epochs, lr_min)
#      12     return learn
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
learn = train_on_dataset(datasets[0], learn=learn, epochs=20)
# Out:
# Training model on dataset: CHEMBL205
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.085320</td>
#       <td>0.132725</td>
#       <td>0.961271</td>
#       <td>0.816380</td>
#       <td>0.716937</td>
#       <td>0.947853</td>
#       <td>0.984275</td>
#       <td>0.804888</td>
#       <td>00:51</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.079221</td>
#       <td>0.131259</td>
#       <td>0.962664</td>
#       <td>0.821333</td>
#       <td>0.726415</td>
#       <td>0.944785</td>
#       <td>0.984329</td>
#       <td>0.809513</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.094397</td>
#       <td>0.116270</td>
#       <td>0.964614</td>
#       <td>0.826739</td>
#       <td>0.744472</td>
#       <td>0.929448</td>
#       <td>0.984334</td>
#       <td>0.813469</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.085856</td>
#       <td>0.130452</td>
#       <td>0.962664</td>
#       <td>0.821333</td>
#       <td>0.726415</td>
#       <td>0.944785</td>
#       <td>0.984376</td>
#       <td>0.809513</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.084821</td>
#       <td>0.127135</td>
#       <td>0.962664</td>
#       <td>0.819892</td>
#       <td>0.729665</td>
#       <td>0.935583</td>
#       <td>0.984303</td>
#       <td>0.807110</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.089998</td>
#       <td>0.132398</td>
#       <td>0.962385</td>
#       <td>0.820240</td>
#       <td>0.724706</td>
#       <td>0.944785</td>
#       <td>0.984484</td>
#       <td>0.808415</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.083510</td>
#       <td>0.115843</td>
#       <td>0.965450</td>
#       <td>0.831063</td>
#       <td>0.747549</td>
#       <td>0.935583</td>
#       <td>0.984436</td>
#       <td>0.818431</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.088606</td>
#       <td>0.132993</td>
#       <td>0.960713</td>
#       <td>0.813245</td>
#       <td>0.715618</td>
#       <td>0.941718</td>
#       <td>0.984424</td>
#       <td>0.801072</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0